# %%
from httpx import Client
import logging
tf_api_session = Client()
# This caches the items less likely to change (if at all during the
# course of the event.  The field software probably shouldn't be
# called until this is set up finally and tournaments are started.
import time
from pprint import pprint
import json

# Probably shouldn't be hardcoded but whatever.
arena_secrets = {
    "truefinals": {
        "api_key":"",
        "user_id":""
    },
}

def makeAPIRequest(endpoint: str) -> list:
    api_key = arena_secrets['truefinals']['api_key']
    user_id = arena_secrets['truefinals']['user_id']
    credentials = {"user_id": user_id, "api_key": api_key}

    headers = {
        "x-api-user-id": credentials["user_id"],
        "x-api-key": credentials["api_key"],
    }

    root_endpoint = """https://truefinals.com/api"""

    logging.info(f"value {endpoint} is not in cache, trying request now!")
    resp = tf_api_session.get((f"{root_endpoint}{endpoint}"), headers=headers)
    return resp


def getAllGames(tournamentID: str) -> list[dict]:
    return makeAPIRequest(
        f"/v1/tournaments/{tournamentID}/games"
    )

def getTournamentPlayers(tournamentID: str) -> list[dict]:
    return makeAPIRequest(
        f"/v1/tournaments/{tournamentID}/players"
    )

# %%
# This has to be expanded on the off chance there are more events, wow!  neat!

event_codes = [
    {'name':'Mechanical Mayhem Season 3','ant':'e30df56f90ce4728', 'plant':'56937eb314654f13','beetle':'a7c1cde165524cef'},
    {'name':'Seasonal Smackdown 2024', 'ant':'9d1f08d48c3945de', 'plant':'3a3d36b1473c4b9d', 'beetle': '2146ec5eb37a47ba'},
    {'name':'Mechanical Mayhem Winter 2025','ant':'c8309bfc63dd4768','plant':'','beetle':'aed8209c62364a66'}
]

# %%
results = {}

for event in event_codes:
    # We remove the name key so we only get the weightclass results.
    # We also discard none / empty string values so we can template / copy again.
    valid_tournament_weightclasses = [x for x in event.keys() if x not in ['name'] and event[x] not in [None, '']]

    for t_weightclass in valid_tournament_weightclasses:
        if t_weightclass not in results:
            results[t_weightclass] = {}

        weightclass_competitors = getTournamentPlayers(event[t_weightclass]).json()
        time.sleep(5)
        for competitor in weightclass_competitors:
            simple_competitor_name = " ".join([x for x in competitor['name'].lower().strip().replace("'","").split(" ") if x != ""])

            if simple_competitor_name not in results[t_weightclass]:
                results[t_weightclass][simple_competitor_name] = [[event[t_weightclass], competitor['placement']]]
            else:
                results[t_weightclass][simple_competitor_name].append([event[t_weightclass], competitor['placement']])
from pprint import pprint
pprint(results)
# Out:
# {'ant': {'aerator': [['9d1f08d48c3945de', 7]],
#          'banana hammer': [['9d1f08d48c3945de', 17]],
#          'big chungus': [['c8309bfc63dd4768', 9]],
#          'birthstone': [['e30df56f90ce4728', 5]],
#          'bort': [['e30df56f90ce4728', 4],
#                   ['9d1f08d48c3945de', 5],
#                   ['c8309bfc63dd4768', 2]],
#          'bumblebee': [['e30df56f90ce4728', 2], ['9d1f08d48c3945de', 2]],
#          'burning hand': [['9d1f08d48c3945de', 9]],
#          'caesar': [['e30df56f90ce4728', 13]],
#          'captain flatface': [['e30df56f90ce4728', 17]],
#          'control freak': [['9d1f08d48c3945de', 5], ['c8309bfc63dd4768', 1]],
#          'doink': [['9d1f08d48c3945de', 4]],
#          'dulce de lucha': [['9d1f08d48c3945de', 1]],
#          'flatline': [['e30df56f90ce4728', 9]],
#          'floormidable': [['e30df56f90ce4728', 13]],
#          'harlequin': [['e30df56f90ce4728', 1]],
#          'heat mizer': [['9d1f08d48c3945de', 25]],
#          'humuhumu': [['9d1f08d48c3945de', 9]],
#          'hypoviper': [['e30df56f90ce4728', 17], ['9d1f08d48c3945de', 25]],
#          'hypoviper ii': [['c8309bfc63dd4768', 7]],
#          'ipso facto': [['9d1f08d48c3945de', 17], ['c8309bfc63dd4768', 4]],
#          'jersey devil': [['e30df56f90ce4728', 9]],
#          'kronos': [['c8309bfc63dd4768', 9]],
#          'lil chef': [['9d1f08d48c3945de', 9]],
#          'lilliputian': [['e30df56f90ce4728', 7],
#                          ['9d1f08d48c3945de', 3],
#                          ['c8309bfc63dd4768', 5]],
#          'little mac': [['e30df56f90ce4728', 5]],
#          'lunar': [['9d1f08d48c3945de', 25]],
#          'micro': [['e30df56f90ce4728', 9]],
#          'minibee': [['9d1f08d48c3945de', 7]],
#          'mo': [['e30df56f90ce4728', 3]],
#          'monster zero': [['9d1f08d48c3945de', 13], ['c8309bfc63dd4768', 3]],
#          'nick san dx': [['9d1f08d48c3945de', 33]],
#          'noreaster': [['9d1f08d48c3945de', 25]],
#          'oreo': [['9d1f08d48c3945de', 17]],
#          'phantom': [['9d1f08d48c3945de', 17], ['c8309bfc63dd4768', 7]],
#          'power off': [['e30df56f90ce4728', 17], ['c8309bfc63dd4768', 5]],
#          'pretty little psycho': [['9d1f08d48c3945de', 9]],
#          'rabot': [['9d1f08d48c3945de', 25]],
#          'rapscallion': [['9d1f08d48c3945de', 17]],
#          'sabre2th': [['e30df56f90ce4728', 13]],
#          'shin kicker': [['e30df56f90ce4728', 13], ['9d1f08d48c3945de', 13]],
#          'soul crusher': [['9d1f08d48c3945de', 25], ['c8309bfc63dd4768', 13]],
#          'sour cream': [['9d1f08d48c3945de', 13]],
#          'spongebob': [['e30df56f90ce4728', 17]],
#          'sushi': [['9d1f08d48c3945de', 25], ['c8309bfc63dd4768', 9]],
#          'taipan': [['9d1f08d48c3945de', 25]],
#          'tartarus': [['e30df56f90ce4728', 9], ['9d1f08d48c3945de', 13]],
#          'tax evasion': [['9d1f08d48c3945de', 17]],
#          'trash panda': [['9d1f08d48c3945de', 17]],
#          'uh-oh': [['e30df56f90ce4728', 17]],
#          'uproar': [['c8309bfc63dd4768', 9]],
#          'violet flame': [['e30df56f90ce4728', 7], ['9d1f08d48c3945de', 17]]},
#  'beetle': {'3 ants': [['aed8209c62364a66', None]],
#             'anubis': [['a7c1cde165524cef', 9], ['2146ec5eb37a47ba', 3]],
#             'arc flash': [['2146ec5eb37a47ba', 17]],
#             'backfire': [['aed8209c62364a66', 5]],
#             'bagheera': [['2146ec5eb37a47ba', 17], ['aed8209c62364a66', 3]],
#             'bean supreme': [['2146ec5eb37a47ba', 17]],
#             'breakneck nyan nyan': [['aed8209c62364a66', 4]],
#             'brzrkr': [['2146ec5eb37a47ba', 9]],
#             'burnt marshmallow': [['2146ec5eb37a47ba', 33]],
#             'cereal killer': [['a7c1cde165524cef', 7]],
#             'cheesestyle': [['2146ec5eb37a47ba', 9]],
#             'crazy frog': [['2146ec5eb37a47ba', 33]],
#             'devolver': [['2146ec5eb37a47ba', 33]],
#             'drumder child': [['2146ec5eb37a47ba', 7]],
#             'eruption': [['2146ec5eb37a47ba', 1]],
#             'fightamix': [['a7c1cde165524cef', 13]],
#             'half-life': [['2146ec5eb37a47ba', 4]],
#             'halflife ii': [['a7c1cde165524cef', 5]],
#             'iodine': [['aed8209c62364a66', 9]],
#             'jackalope': [['a7c1cde165524cef', 17], ['2146ec5eb37a47ba', 17]],
#             'joe': [['2146ec5eb37a47ba', 25]],
#             'kilico': [['2146ec5eb37a47ba', 33], ['aed8209c62364a66', 9]],
#             'kittykat': [['a7c1cde165524cef', 17], ['2146ec5eb37a47ba', 9]],
#             'last minute lenny': [['2146ec5eb37a47ba', 25]],
#             'lilli': [['aed8209c62364a66', 5]],
#             'manticore': [['aed8209c62364a66', 9]],
#             'marvin': [['a7c1cde165524cef', 9],
#                        ['2146ec5eb37a47ba', 17],
#                        ['aed8209c62364a66', 7]],
#             'master control bot': [['2146ec5eb37a47ba', 25]],
#             'meater beater': [['2146ec5eb37a47ba', 33]],
#             'melon baller': [['a7c1cde165524cef', 17],
#                              ['2146ec5eb37a47ba', 13]],
#             'mothership': [['2146ec5eb37a47ba', 13]],
#             'power on': [['a7c1cde165524cef', 13],
#                          ['2146ec5eb37a47ba', 17],
#                          ['aed8209c62364a66', 7]],
#             'prince': [['a7c1cde165524cef', 1], ['2146ec5eb37a47ba', 7]],
#             'raging sunder': [['2146ec5eb37a47ba', 17]],
#             'rainbow aioli': [['a7c1cde165524cef', 13]],
#             'red flag': [['a7c1cde165524cef', 5], ['2146ec5eb37a47ba', 9]],
#             'red panda': [['a7c1cde165524cef', 9]],
#             'redline': [['2146ec5eb37a47ba', 5]],
#             'sir slicey': [['2146ec5eb37a47ba', 2]],
#             'sir spinny': [['a7c1cde165524cef', 3]],
#             'sting operation': [['a7c1cde165524cef', 7],
#                                 ['2146ec5eb37a47ba', 5],
#                                 ['aed8209c62364a66', 1]],
#             'the big bill': [['2146ec5eb37a47ba', 25]],
#             'the fool': [['a7c1cde165524cef', 2], ['2146ec5eb37a47ba', 13]],
#             'the throngler': [['a7c1cde165524cef', 9]],
#             'thimbleberry': [['2146ec5eb37a47ba', 25]],
#             'tokyo drisk': [['a7c1cde165524cef', 4]],
#             'toucan': [['2146ec5eb37a47ba', 17]],
#             'uhhh': [['2146ec5eb37a47ba', 25]],
#             'usawgi': [['aed8209c62364a66', 2]],
#             'verticalizer': [['2146ec5eb37a47ba', 13]],
#             'walter': [['a7c1cde165524cef', 13], ['2146ec5eb37a47ba', 25]],
#             'wild magic': [['2146ec5eb37a47ba', 25]]},
#  'plant': {'blizzard': [['3a3d36b1473c4b9d', 13]],
#            'charmander': [['3a3d36b1473c4b9d', 13]],
#            'cheeks': [['3a3d36b1473c4b9d', 17]],
#            'crash panda': [['3a3d36b1473c4b9d', 5]],
#            'deatharang': [['3a3d36b1473c4b9d', 2]],
#            'devastator': [['56937eb314654f13', 5]],
#            'dust devil': [['3a3d36b1473c4b9d', 1]],
#            'eschatology': [['56937eb314654f13', 7], ['3a3d36b1473c4b9d', 7]],
#            'f1': [['3a3d36b1473c4b9d', 9]],
#            'hulk smash': [['3a3d36b1473c4b9d', 9]],
#            'kickplate': [['3a3d36b1473c4b9d', 7]],
#            'last minute': [['56937eb314654f13', 7]],
#            'last try bot': [['3a3d36b1473c4b9d', 17]],
#            'meta moon': [['3a3d36b1473c4b9d', 9]],
#            'murderpaws': [['56937eb314654f13', 1]],
#            'oops': [['3a3d36b1473c4b9d', 13]],
#            'shadow': [['3a3d36b1473c4b9d', 9]],
#            'sour cream': [['56937eb314654f13', 2]],
#            'tartarus': [['56937eb314654f13', 4]],
#            'tiny terror': [['3a3d36b1473c4b9d', 4]],
#            'tofu': [['3a3d36b1473c4b9d', 13]],
#            'trampoline': [['56937eb314654f13', 3], ['3a3d36b1473c4b9d', 5]],
#            'tyson': [['3a3d36b1473c4b9d', 3]],
#            'wolverine': [['56937eb314654f13', 5]]}}

# %%
for w in results.keys():
    weightclass = w

    robot_names = results[weightclass].keys()
    #print(robot_names)
    
    for r in robot_names:
        robot_name = r
        finishes = results[weightclass][r]

        for player_finishes in finishes:
            print(','.join([weightclass, robot_name, str(player_finishes[0]), str(player_finishes[1])]))
# Out:
# ant,bumblebee,e30df56f90ce4728,2
# ant,bumblebee,9d1f08d48c3945de,2
# ant,lilliputian,e30df56f90ce4728,7
# ant,lilliputian,9d1f08d48c3945de,3
# ant,lilliputian,c8309bfc63dd4768,5
# ant,caesar,e30df56f90ce4728,13
# ant,bort,e30df56f90ce4728,4
# ant,bort,9d1f08d48c3945de,5
# ant,bort,c8309bfc63dd4768,2
# ant,power off,e30df56f90ce4728,17
# ant,power off,c8309bfc63dd4768,5
# ant,harlequin,e30df56f90ce4728,1
# ant,shin kicker,e30df56f90ce4728,13
# ant,shin kicker,9d1f08d48c3945de,13
# ant,jersey devil,e30df56f90ce4728,9
# ant,micro,e30df56f90ce4728,9
# ant,birthstone,e30df56f90ce4728,5
# ant,mo,e30df56f90ce4728,3
# ant,captain flatface,e30df56f90ce4728,17
# ant,floormidable,e30df56f90ce4728,13
# ant,flatline,e30df56f90ce4728,9
# ant,violet flame,e30df56f90ce4728,7
# ant,violet flame,9d1f08d48c3945de,17
# ant,uh-oh,e30df56f90ce4728,17
# ant,sabre2th,e30df56f90ce4728,13
# ant,little mac,e30df56f90ce4728,5
# ant,spongebob,e30df56f90ce4728,17
# ant,hypoviper,e30df56f90ce4728,17
# ant,hypoviper,9d1f08d48c3945de,25
# ant,tartarus,e30df56f90ce4728,9
# ant,tartarus,9d1f08d48c3945de,13
# ant,humuhumu,9d1f08d48c3945de,9
# ant,lil chef,9d1f08d48c3945de,9
# ant,doink,9d1f08d48c3945de,4
# ant,heat mizer,9d1f08d48c3945de,25
# ant,pretty little psycho,9d1f08d48c3945de,9
# ant,rabot,9d1f08d48c3945de,25
# ant,control freak,9d1f08d48c3945de,5
# ant,control freak,c8309bfc63dd4768,1
# ant,tax evasion,9d1f08d48c3945de,17
# ant,taipan,9d1f08d48c3945de,25
# ant,lunar,9d1f08d48c3945de,25
# ant,burning hand,9d1f08d48c3945de,9
# ant,rapscallion,9d1f08d48c3945de,17
# ant,minibee,9d1f08d48c3945de,7
# ant,dulce de lucha,9d1f08d48c3945de,1
# ant,trash panda,9d1f08d48c3945de,17
# ant,sour cream,9d1f08d48c3945de,13
# ant,phantom,9d1f08d48c3945de,17
# ant,phantom,c8309bfc63dd4768,7
# ant,monster zero,9d1f08d48c3945de,13
# ant,monster zero,c8309bfc63dd4768,3
# ant,ipso facto,9d1f08d48c3945de,17
# ant,ipso facto,c8309bfc63dd4768,4
# ant,aerator,9d1f08d48c3945de,7
# ant,banana hammer,9d1f08d48c3945de,17
# ant,oreo,9d1f08d48c3945de,17
# ant,noreaster,9d1f08d48c3945de,25
# ant,soul crusher,9d1f08d48c3945de,25
# ant,soul crusher,c8309bfc63dd4768,13
# ant,sushi,9d1f08d48c3945de,25
# ant,sushi,c8309bfc63dd4768,9
# ant,nick san dx,9d1f08d48c3945de,33
# ant,hypoviper ii,c8309bfc63dd4768,7
# ant,uproar,c8309bfc63dd4768,9
# ant,big chungus,c8309bfc63dd4768,9
# ant,kronos,c8309bfc63dd4768,9
# plant,wolverine,56937eb314654f13,5
# plant,murderpaws,56937eb314654f13,1
# plant,last minute,56937eb314654f13,7
# plant,trampoline,56937eb314654f13,3
# plant,trampoline,3a3d36b1473c4b9d,5
# plant,tartarus,56937eb314654f13,4
# plant,devastator,56937eb314654f13,5
# plant,sour cream,56937eb314654f13,2
# plant,eschatology,56937eb314654f13,7
# plant,eschatology,3a3d36b1473c4b9d,7
# plant,tyson,3a3d36b1473c4b9d,3
# plant,tiny terror,3a3d36b1473c4b9d,4
# plant,meta moon,3a3d36b1473c4b9d,9
# plant,charmander,3a3d36b1473c4b9d,13
# plant,oops,3a3d36b1473c4b9d,13
# plant,shadow,3a3d36b1473c4b9d,9
# plant,hulk smash,3a3d36b1473c4b9d,9
# plant,tofu,3a3d36b1473c4b9d,13
# plant,crash panda,3a3d36b1473c4b9d,5
# plant,kickplate,3a3d36b1473c4b9d,7
# plant,deatharang,3a3d36b1473c4b9d,2
# plant,f1,3a3d36b1473c4b9d,9
# plant,dust devil,3a3d36b1473c4b9d,1
# plant,blizzard,3a3d36b1473c4b9d,13
# plant,last try bot,3a3d36b1473c4b9d,17
# plant,cheeks,3a3d36b1473c4b9d,17
# beetle,sir spinny,a7c1cde165524cef,3
# beetle,sting operation,a7c1cde165524cef,7
# beetle,sting operation,2146ec5eb37a47ba,5
# beetle,sting operation,aed8209c62364a66,1
# beetle,prince,a7c1cde165524cef,1
# beetle,prince,2146ec5eb37a47ba,7
# beetle,the fool,a7c1cde165524cef,2
# beetle,the fool,2146ec5eb37a47ba,13
# beetle,tokyo drisk,a7c1cde165524cef,4
# beetle,cereal killer,a7c1cde165524cef,7
# beetle,walter,a7c1cde165524cef,13
# beetle,walter,2146ec5eb37a47ba,25
# beetle,marvin,a7c1cde165524cef,9
# beetle,marvin,2146ec5eb37a47ba,17
# beetle,marvin,aed8209c62364a66,7
# beetle,power on,a7c1cde165524cef,13
# beetle,power on,2146ec5eb37a47ba,17
# beetle,power on,aed8209c62364a66,7
# beetle,the throngler,a7c1cde165524cef,9
# beetle,fightamix,a7c1cde165524cef,13
# beetle,kittykat,a7c1cde165524cef,17
# beetle,kittykat,2146ec5eb37a47ba,9
# beetle,anubis,a7c1cde165524cef,9
# beetle,anubis,2146ec5eb37a47ba,3
# beetle,jackalope,a7c1cde165524cef,17
# beetle,jackalope,2146ec5eb37a47ba,17
# beetle,red flag,a7c1cde165524cef,5
# beetle,red flag,2146ec5eb37a47ba,9
# beetle,melon baller,a7c1cde165524cef,17
# beetle,melon baller,2146ec5eb37a47ba,13
# beetle,halflife ii,a7c1cde165524cef,5
# beetle,rainbow aioli,a7c1cde165524cef,13
# beetle,red panda,a7c1cde165524cef,9
# beetle,redline,2146ec5eb37a47ba,5
# beetle,sir slicey,2146ec5eb37a47ba,2
# beetle,arc flash,2146ec5eb37a47ba,17
# beetle,last minute lenny,2146ec5eb37a47ba,25
# beetle,drumder child,2146ec5eb37a47ba,7
# beetle,uhhh,2146ec5eb37a47ba,25
# beetle,toucan,2146ec5eb37a47ba,17
# beetle,joe,2146ec5eb37a47ba,25
# beetle,thimbleberry,2146ec5eb37a47ba,25
# beetle,kilico,2146ec5eb37a47ba,33
# beetle,kilico,aed8209c62364a66,9
# beetle,brzrkr,2146ec5eb37a47ba,9
# beetle,wild magic,2146ec5eb37a47ba,25
# beetle,raging sunder,2146ec5eb37a47ba,17
# beetle,meater beater,2146ec5eb37a47ba,33
# beetle,bagheera,2146ec5eb37a47ba,17
# beetle,bagheera,aed8209c62364a66,3
# beetle,cheesestyle,2146ec5eb37a47ba,9
# beetle,verticalizer,2146ec5eb37a47ba,13
# beetle,master control bot,2146ec5eb37a47ba,25
# beetle,devolver,2146ec5eb37a47ba,33
# beetle,burnt marshmallow,2146ec5eb37a47ba,33
# beetle,eruption,2146ec5eb37a47ba,1
# beetle,crazy frog,2146ec5eb37a47ba,33
# beetle,mothership,2146ec5eb37a47ba,13
# beetle,bean supreme,2146ec5eb37a47ba,17
# beetle,half-life,2146ec5eb37a47ba,4
# beetle,the big bill,2146ec5eb37a47ba,25
# beetle,usawgi,aed8209c62364a66,2
# beetle,breakneck nyan nyan,aed8209c62364a66,4
# beetle,backfire,aed8209c62364a66,5
# beetle,manticore,aed8209c62364a66,9
# beetle,iodine,aed8209c62364a66,9
# beetle,lilli,aed8209c62364a66,5
# beetle,3 ants,aed8209c62364a66,None
